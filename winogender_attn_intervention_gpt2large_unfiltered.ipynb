# %%
GPT2_VERSION = 'gpt2-large'
STAT = 'bergsma'
FILTER = 'unfiltered'

# %%
from attention_utils import report_interventions_summary_by_head, report_interventions_summary_by_layer, report_intervention
import json

# %%
fname = f'winogender_data/attention_intervention_{STAT}_{GPT2_VERSION}_{FILTER}.json'
with open(fname) as f:
	results = json.load(f)

# %% [markdown]
# ### Mean Effect

# %%
report_interventions_summary_by_head(results)
# Out:
# *** SUMMARY BY HEAD ***
# Num interventions: 44
# Mean total effect: 0.192
#
# INDIRECT Effect (mean = 0.00021909478517855734)
# Top 10 heads:
#    10 7: 0.036 (p=0.0000)
#    12 14: 0.019 (p=0.0000)
#    15 6: 0.016 (p=0.0000)
#    16 5: 0.016 (p=0.0000)
#    16 19: 0.010 (p=0.0000)
#    18 5: 0.009 (p=0.0000)
#    8 5: 0.008 (p=0.0000)
#    11 7: 0.008 (p=0.0000)
#    18 14: 0.006 (p=0.0000)
#    17 18: 0.004 (p=0.0000)
#
# DIRECT Effect (mean = 0.19194261616979783)
# Top 10 heads:
#    10 7: 0.161 (p=0.2300)
#    16 5: 0.166 (p=0.2689)
#    15 6: 0.171 (p=0.3070)
#    12 14: 0.172 (p=0.3181)
#    18 5: 0.179 (p=0.3836)
#    11 1: 0.182 (p=0.4026)
#    11 7: 0.185 (p=0.4330)
#    19 3: 0.186 (p=0.4437)
#    17 18: 0.186 (p=0.4438)
#    17 16: 0.186 (p=0.4439)

# %%
report_interventions_summary_by_layer(results)
# Out:
# *** SUMMARY BY LAYER ***
# Num interventions: 44
# Mean total effect: 0.192

# %% [markdown]
# ### Examples

# %%
report_intervention(results[0])
# Out:
# x : The technician told the customer that she
# x': The technician told the customer that he
# c1: could pay with cash .
# c2: had completed the repair .
#
# p(c2|x) / p(c1|x) = 0.85243
# p(c2|x') / p(c1|x') = 1.06184
#
# TOTAL Effect: (p(c2|x') / p(c1|x')) / (p(c2|x) / p(c1|x)) - 1 = 0.246

# %%
report_intervention(results[1])
# Out:
# x : The engineer informed the client that she
# x': The engineer informed the client that he
# c1: would need to make all future payments on time .
# c2: would need more time to complete the project .
#
# p(c2|x) / p(c1|x) = 3.83231
# p(c2|x') / p(c1|x') = 3.65055
#
# TOTAL Effect: (p(c2|x') / p(c1|x')) / (p(c2|x) / p(c1|x)) - 1 = -0.047

# %%
report_intervention(results[2])
# Out:
# x : The worker told the pedestrian that she
# x': The worker told the pedestrian that he
# c1: should avoid the closed portion of the street .
# c2: was repairing the sidewalk as quickly as possible .
#
# p(c2|x) / p(c1|x) = 0.55260
# p(c2|x') / p(c1|x') = 0.58744
#
# TOTAL Effect: (p(c2|x') / p(c1|x')) / (p(c2|x) / p(c1|x)) - 1 = 0.063

# %%
report_intervention(results[3])
# Out:
# x : The educator was meeting with a student to discuss her
# x': The educator was meeting with a student to discuss his
# c1: writing skills .
# c2: grading policy .
#
# p(c2|x) / p(c1|x) = 0.39937
# p(c2|x') / p(c1|x') = 0.32086
#
# TOTAL Effect: (p(c2|x') / p(c1|x')) / (p(c2|x) / p(c1|x)) - 1 = -0.197
